# %%
"""import pandas as pd
import time
import requests
from io import StringIO

map_key = "b73850f35cfea7f219a3969b6df1d9a6"
api_url = f"https://firms.modaps.eosdis.nasa.gov/usfs/api/area/csv/{map_key}/VIIRS_SNPP_NRT/world/1"

while True:
    response = requests.get(api_url)
    if response.status_code == 200:
        df = pd.read_csv(StringIO(response.text))
        print(f"Data loaded: {len(df)}")
    else:
        print("Error") 
    time.sleep(60)"""
# Out:
# 'import pandas as pd\nimport time\nimport requests\nfrom io import StringIO\n\nmap_key = "b73850f35cfea7f219a3969b6df1d9a6"\napi_url = f"https://firms.modaps.eosdis.nasa.gov/usfs/api/area/csv/{map_key}/VIIRS_SNPP_NRT/world/1"\n\nwhile True:\n    response = requests.get(api_url)\n    if response.status_code == 200:\n        df = pd.read_csv(StringIO(response.text))\n        print(f"Data loaded: {len(df)}")\n    else:\n        print("Error") \n    time.sleep(60)'
